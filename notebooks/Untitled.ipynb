# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from util import make_mirna_nanostring_df

# %%
df = pd.read_csv('../data/Streptococcus_gordonii/8 weeks S.gordonii infection.csv', index_col='File Name')
df.head()
# Out:
#              Unnamed: 1 Unnamed: 2 20220829_run10_GVI-8W-10_12.RCC  \
# File Name
# Description         NaN        NaN                             NaN
# Sample ID           NaN        NaN                       GVI-8W-10
# Owner               NaN        NaN       Aravindraja Chairmandurai
# Sample Date         NaN        NaN                       8/29/2022
# File Version        NaN        NaN                             1.7
#
#              20220829_run10_GVI-8W-1_03.RCC 20220829_run10_GVI-8W-2_04.RCC  \
# File Name
# Description                             NaN                            NaN
# Sample ID                          GVI-8W-1                       GVI-8W-2
# Owner             Aravindraja Chairmandurai      Aravindraja Chairmandurai
# Sample Date                       8/29/2022                      8/29/2022
# File Version                            1.7                            1.7
#
#              20220829_run10_GVI-8W-3_05.RCC 20220829_run10_GVI-8W-4_06.RCC  \
# ...

# %%
file_names = [
    '../data/Streptococcus_gordonii/8 weeks S.gordonii infection.csv', 
    '../data/Streptococcus_gordonii/8 weeks SHAM infection.csv', 
    '../data/Streptococcus_gordonii/16 weeks S. gordonii infection.csv', 
    '../data/Streptococcus_gordonii/16 weeks SHAM infection.csv'
]
cohort_names = ['sg_8_weeks', 'sham_8_weeks', 'sg_16_weeks', 'sham_16_weeks']
list(zip(file_names, cohort_names))
# Out:
# [('../data/Streptococcus_gordonii/8 weeks S.gordonii infection.csv',
#   'sg_8_weeks'),
#  ('../data/Streptococcus_gordonii/8 weeks SHAM infection.csv', 'sham_8_weeks'),
#  ('../data/Streptococcus_gordonii/16 weeks S. gordonii infection.csv',
#   'sg_16_weeks'),
#  ('../data/Streptococcus_gordonii/8 weeks SHAM infection.csv',
#   'sham_16_weeks')]

# %%
make_mirna_nanostring_df(file_names, cohort_names)
# Out:
#             cohort_key         cohort mouse_number  \
# 0     sg_8_weeks_10_12     sg_8_weeks        10_12
# 1      sg_8_weeks_1_03     sg_8_weeks         1_03
# 2      sg_8_weeks_2_04     sg_8_weeks         2_04
# 3      sg_8_weeks_3_05     sg_8_weeks         3_05
# 4      sg_8_weeks_4_06     sg_8_weeks         4_06
# 5      sg_8_weeks_5_07     sg_8_weeks         5_07
# 6      sg_8_weeks_6_08     sg_8_weeks         6_08
# 7      sg_8_weeks_7_09     sg_8_weeks         7_09
# 8      sg_8_weeks_8_10     sg_8_weeks         8_10
# 9      sg_8_weeks_9_11     sg_8_weeks         9_11
# 0   sham_8_weeks_10_12   sham_8_weeks        10_12
# 1    sham_8_weeks_1_03   sham_8_weeks         1_03
# 2    sham_8_weeks_2_04   sham_8_weeks         2_04
# 3    sham_8_weeks_3_05   sham_8_weeks         3_05
# 4    sham_8_weeks_4_06   sham_8_weeks         4_06
# 5    sham_8_weeks_5_07   sham_8_weeks         5_07
# 6    sham_8_weeks_6_08   sham_8_weeks         6_08
# ...

# %%
df.iloc[1, :].values
sample_ids = df.loc['Sample ID', :].values
sample_ids
# Out:
# array([nan, nan, 'GVI-8W-10', 'GVI-8W-1', 'GVI-8W-2', 'GVI-8W-3',
#        'GVI-8W-4', 'GVI-8W-5', 'GVI-8W-6', 'GVI-8W-7', 'GVI-8W-8',
#        'GVI-8W-9'], dtype=object)

# %%
endogenous_df = df.loc['Endogenous'].copy()
endogenous_df.head()
# Out:
#                    Unnamed: 1    Unnamed: 2 20220829_run10_GVI-8W-10_12.RCC  \
# Name
# Endogenous  mcmv-miR-M23-1-3p  MIMAT0005543                              89
# Endogenous  mcmv-miR-M23-1-5p  MIMAT0005542                              80
# Endogenous     mcmv-miR-M23-2  MIMAT0005545                              22
# Endogenous     mcmv-miR-M44-1  MIMAT0005546                              37
# Endogenous     mcmv-miR-M55-1  MIMAT0005547                              61
#
#            20220829_run10_GVI-8W-1_03.RCC 20220829_run10_GVI-8W-2_04.RCC  \
# Name
# Endogenous                             88                             75
# Endogenous                             60                             82
# Endogenous                             18                             12
# Endogenous                             14                             22
# Endogenous                             52                             63
#
# ...

# %%
df.columns[2:]
# Out:
# Index(['20220829_run10_GVI-8W-10_12.RCC', '20220829_run10_GVI-8W-1_03.RCC',
#        '20220829_run10_GVI-8W-2_04.RCC', '20220829_run10_GVI-8W-3_05.RCC',
#        '20220829_run10_GVI-8W-4_06.RCC', '20220829_run10_GVI-8W-5_07.RCC',
#        '20220829_run10_GVI-8W-6_08.RCC', '20220829_run10_GVI-8W-7_09.RCC',
#        '20220829_run10_GVI-8W-8_10.RCC', '20220829_run10_GVI-8W-9_11.RCC'],
#       dtype='object')

# %%
# endogenous_df = endogenous_df.assign(miR= "".join(endogenous_df.iloc[0] + " (" + endogenous_df.iloc[1] + ")")).drop(endogenous_df.columns[[0,1]], axis=1)
# first_col = endogenous_df.pop('miR')
# endogenous_df.insert(0, 'miR', first_col)
# endogenous_df
# endogenous_df.assign(miR= "".join(endogenous_df.iloc[0] + " (" + endogenous_df.iloc[1] + ")")).drop(endogenous_df.columns[[0,1]], axis=1).head()

# %%
endogenous_df
# Out:
#                    Unnamed: 1    Unnamed: 2 20220829_run10_GVI-8W-10_12.RCC  \
# Name
# Endogenous  mcmv-miR-M23-1-3p  MIMAT0005543                              89
# Endogenous  mcmv-miR-M23-1-5p  MIMAT0005542                              80
# Endogenous     mcmv-miR-M23-2  MIMAT0005545                              22
# Endogenous     mcmv-miR-M44-1  MIMAT0005546                              37
# Endogenous     mcmv-miR-M55-1  MIMAT0005547                              61
# ...                       ...           ...                             ...
# Endogenous         mmu-miR-93  MIMAT0000540                             245
# Endogenous         mmu-miR-96  MIMAT0000541                             392
# Endogenous         mmu-miR-98  MIMAT0000545                             790
# Endogenous        mmu-miR-99a  MIMAT0000131                            5559
# Endogenous        mmu-miR-99b  MIMAT0000132                             364
#
# ...

# %%
bar
# Out:
#                                          miR 20220829_run10_GVI-8W-10_12.RCC  \
# Name
# Endogenous  mcmv-miR-M23-1-3p (MIMAT0005543)                              89
# Endogenous  mcmv-miR-M23-1-5p (MIMAT0005542)                              80
# Endogenous     mcmv-miR-M23-2 (MIMAT0005545)                              22
# Endogenous     mcmv-miR-M44-1 (MIMAT0005546)                              37
# Endogenous     mcmv-miR-M55-1 (MIMAT0005547)                              61
#
#            20220829_run10_GVI-8W-1_03.RCC 20220829_run10_GVI-8W-2_04.RCC  \
# Name
# Endogenous                             88                             75
# Endogenous                             60                             82
# Endogenous                             18                             12
# Endogenous                             14                             22
# Endogenous                             52                             63
#
# ...

# %%
bar = df.loc['Endogenous'].copy()[0:5]

# endogenous_df.insert(0, 'miR', '')
# endogenous_df['miR']=endogenous_df.iloc[:, 1] + ' (' + endogenous_df.iloc[:, 2] + ')'
# endogenous_df.drop(endogenous_df.columns[[1, 2]], axis=1, inplace=True)
# tx_df = endogenous_df.transpose().reset_index()
# tx_df.columns = tx_df.iloc[0]
# # tx_df.drop([0], inplace=True)
# tx_df.drop([0])
# tx_df.iloc[0]
# tx_df
# bar = (
#     df.loc['Endogenous'].copy()[0:5]
#     .assign(miR=(lambda x: x.iloc[:, 0] + ' (' + x.iloc[:, 1] + ')'))
#     .drop(x.columns[[0,1]], axis=1)
# )
# bar.insert(0, 'miR', bar.pop('miR'))

# tx_df = bar.transpose().reset_index()
# tx_df.columns = tx_df.iloc[0]
# tx_df
baz = bar.iloc[:, 2:].transpose()
baz.columns = miR_names
baz
# Out:
#                                 mcmv-miR-M23-1-3p (MIMAT0005543)  \
# 20220829_run10_GVI-8W-10_12.RCC                               89
# 20220829_run10_GVI-8W-1_03.RCC                                88
# 20220829_run10_GVI-8W-2_04.RCC                                75
# 20220829_run10_GVI-8W-3_05.RCC                                59
# 20220829_run10_GVI-8W-4_06.RCC                                94
# 20220829_run10_GVI-8W-5_07.RCC                                80
# 20220829_run10_GVI-8W-6_08.RCC                               114
# 20220829_run10_GVI-8W-7_09.RCC                               108
# 20220829_run10_GVI-8W-8_10.RCC                               112
# 20220829_run10_GVI-8W-9_11.RCC                                92
#
#                                 mcmv-miR-M23-1-5p (MIMAT0005542)  \
# 20220829_run10_GVI-8W-10_12.RCC                               80
# 20220829_run10_GVI-8W-1_03.RCC                                60
# ...

# %%
x.pop('miR')
# Out:
# Name
# Endogenous    mcmv-miR-M23-1-3p (MIMAT0005543)
# Endogenous    mcmv-miR-M23-1-5p (MIMAT0005542)
# Endogenous       mcmv-miR-M23-2 (MIMAT0005545)
# Endogenous       mcmv-miR-M44-1 (MIMAT0005546)
# Endogenous       mcmv-miR-M55-1 (MIMAT0005547)
# Name: miR, dtype: object

# %%
endogenous_df = df.loc['Endogenous'].copy()[0:5]

endogenous_df.insert(0, 'miR', '')
endogenous_df['miR']=endogenous_df.iloc[:, 1] + ' (' + endogenous_df.iloc[:, 2] + ')'
endogenous_df.drop(endogenous_df.columns[[1, 2]], axis=1, inplace=True)
tx_df = endogenous_df.transpose().reset_index()
tx_df.columns = tx_df.iloc[0]
# tx_df.drop([0], inplace=True)
tx_df.drop([0])
# tx_df.iloc[0]
# tx_df
# Out:
# 0                               miR mcmv-miR-M23-1-3p (MIMAT0005543)  \
# 1   20220829_run10_GVI-8W-10_12.RCC                               89
# 2    20220829_run10_GVI-8W-1_03.RCC                               88
# 3    20220829_run10_GVI-8W-2_04.RCC                               75
# 4    20220829_run10_GVI-8W-3_05.RCC                               59
# 5    20220829_run10_GVI-8W-4_06.RCC                               94
# 6    20220829_run10_GVI-8W-5_07.RCC                               80
# 7    20220829_run10_GVI-8W-6_08.RCC                              114
# 8    20220829_run10_GVI-8W-7_09.RCC                              108
# 9    20220829_run10_GVI-8W-8_10.RCC                              112
# 10   20220829_run10_GVI-8W-9_11.RCC                               92
#
# 0  mcmv-miR-M23-1-5p (MIMAT0005542) mcmv-miR-M23-2 (MIMAT0005545)  \
# 1                                80                            22
# 2                                60                            18
# ...

# %%
endogenous_df
# Out:
#                    Unnamed: 1    Unnamed: 2 20220829_run10_GVI-8W-10_12.RCC  \
# Name
# Endogenous  mcmv-miR-M23-1-3p  MIMAT0005543                              89
# Endogenous  mcmv-miR-M23-1-5p  MIMAT0005542                              80
# Endogenous     mcmv-miR-M23-2  MIMAT0005545                              22
# Endogenous     mcmv-miR-M44-1  MIMAT0005546                              37
# Endogenous     mcmv-miR-M55-1  MIMAT0005547                              61
# ...                       ...           ...                             ...
# Endogenous         mmu-miR-93  MIMAT0000540                             245
# Endogenous         mmu-miR-96  MIMAT0000541                             392
# Endogenous         mmu-miR-98  MIMAT0000545                             790
# Endogenous        mmu-miR-99a  MIMAT0000131                            5559
# Endogenous        mmu-miR-99b  MIMAT0000132                             364
#
# ...

# %%
# endogenous_df.assign(
#     miR="".join(endogenous_df.iloc[0] + " (" + endogenous_df.iloc[1] + ")")
# )
# endogenous_df.assign(
#     miR= "".join(endogenous_df.iloc[0] + " (" + endogenous_df.iloc[1] + ")")
# )
names = list(endogenous_df.iloc[0] + " (" + endogenous_df.iloc[1] + ")")
"".join(endogenous_df.iloc[0] + " (" + endogenous_df.iloc[1] + ")")
# Out:
# 'mcmv-miR-M23-1-3p (mcmv-miR-M23-1-5p)MIMAT0005543 (MIMAT0005542)89 (80)88 (60)75 (82)'

# %%
# endogenous_df.iloc[0, :] + " (" + endogenous_df.iloc[1, :] + ")"
endogenous_df.iloc[:, 0]
# Out:
# Name
# Endogenous    88 (60)75 (82)
# Endogenous    88 (60)75 (82)
# Endogenous    88 (60)75 (82)
# Endogenous    88 (60)75 (82)
# Endogenous    88 (60)75 (82)
# Endogenous    88 (60)75 (82)
# Endogenous    88 (60)75 (82)
# Endogenous    88 (60)75 (82)
# Endogenous    88 (60)75 (82)
# Endogenous    88 (60)75 (82)
# Name: miR, dtype: object

# %%
[x.split('-')[-1] for x in sample_ids if x is not np.nan]
# Out:
# ['10', '1', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
df.index.name = 'Name'
df
# Out:
#                Unnamed: 1    Unnamed: 2 20220829_run10_GVI-8W-10_12.RCC  \
# Name
# Description           NaN           NaN                             NaN
# Sample ID             NaN           NaN                       GVI-8W-10
# Owner                 NaN           NaN       Aravindraja Chairmandurai
# Sample Date           NaN           NaN                       8/29/2022
# File Version          NaN           NaN                             1.7
# ...                   ...           ...                             ...
# Endogenous    mmu-miR-99b  MIMAT0000132                             364
# Housekeeping         Actb   NM_007393.1                            4041
# Housekeeping          B2m   NM_009735.3                            1650
# Housekeeping        Gapdh   NM_008084.1                            1560
# Housekeeping        Rpl19   NM_009078.1                            1417
#
#              20220829_run10_GVI-8W-1_03.RCC 20220829_run10_GVI-8W-2_04.RCC  \
# Name
# ...

# %%
sample_ids
# Out:
#    File Name Unnamed: 1 Unnamed: 2 20220829_run10_GVI-8W-10_12.RCC  \
# 1  Sample ID        NaN        NaN                       GVI-8W-10
#
#   20220829_run10_GVI-8W-1_03.RCC 20220829_run10_GVI-8W-2_04.RCC  \
# 1                       GVI-8W-1                       GVI-8W-2
#
#   20220829_run10_GVI-8W-3_05.RCC 20220829_run10_GVI-8W-4_06.RCC  \
# 1                       GVI-8W-3                       GVI-8W-4
#
#   20220829_run10_GVI-8W-5_07.RCC 20220829_run10_GVI-8W-6_08.RCC  \
# 1                       GVI-8W-5                       GVI-8W-6
#
#   20220829_run10_GVI-8W-7_09.RCC 20220829_run10_GVI-8W-8_10.RCC  \
# 1                       GVI-8W-7                       GVI-8W-8
#
#   20220829_run10_GVI-8W-9_11.RCC
# 1                       GVI-8W-9

# %%
endogenous_df = df.loc['Endogenous'].iloc[0:10, 0:5]
endogenous_df
# Out:
#                    Unnamed: 1    Unnamed: 2 20220829_run10_GVI-8W-10_12.RCC  \
# Name
# Endogenous  mcmv-miR-M23-1-3p  MIMAT0005543                              89
# Endogenous  mcmv-miR-M23-1-5p  MIMAT0005542                              80
# Endogenous     mcmv-miR-M23-2  MIMAT0005545                              22
# Endogenous     mcmv-miR-M44-1  MIMAT0005546                              37
# Endogenous     mcmv-miR-M55-1  MIMAT0005547                              61
# Endogenous     mcmv-miR-M87-1  MIMAT0005550                              33
# Endogenous  mcmv-miR-M95-1-3p  MIMAT0005554                              25
# Endogenous  mcmv-miR-M95-1-5p  MIMAT0005553                              17
# Endogenous     mcmv-miR-m01-1  MIMAT0005533                              81
# Endogenous     mcmv-miR-m01-2  MIMAT0005534                              93
#
#            20220829_run10_GVI-8W-1_03.RCC 20220829_run10_GVI-8W-2_04.RCC
# Name
# ...

# %%
cohort_names = ['sg_8_weeks', 'sham_8_weeks', 'sg_16_weeks']

# %%
sample_ids[2:]
df.loc['Sample ID', :].values[2:]
# Out:
# array(['GVI-8W-10', 'GVI-8W-1', 'GVI-8W-2', 'GVI-8W-3', 'GVI-8W-4',
#        'GVI-8W-5', 'GVI-8W-6', 'GVI-8W-7', 'GVI-8W-8', 'GVI-8W-9'],
#       dtype=object)

# %%
def foo(df, cohort=None):
    def create_cohort_key(cohorts, mouse_numbers):
        cohort_keys = [
            c + '_' + n
            for c,n in zip(cohorts, mouse_numbers)
        ]
        return cohort_keys
        
    # get file name values from spreadsheet version of datafame
    # ignore the first two cols
    # the '.RCC' is removed for the file names
    file_names = [col[:-4] for col in df.columns[2:]]
    # print(file_names)
    
    # subset Endogenous results from data
    # and create miR name values from miR and accesson; e.g.: mmu-miR-99b (MIMAT0000132)
    # col[0] is the miR, col[1] is the accession number
    endogenous_df = df.loc['Endogenous'].iloc[:, 0:5]
    miR_names = endogenous_df.iloc[:, 0] + ' (' + endogenous_df.iloc[:, 1] + ')'
    
    # transpose the results ignoring first two columns
    # and assign miR names as column headers
    tx_df = endogenous_df.iloc[:, 2:].transpose()
    tx_df.columns = miR_names
    
    # parse mouse number from file name (e.g.; 20220829_run10_GVI-8W-10_12 -> 10_12)
    mouse_numbers = [x.split('-')[-1] for x in file_names] # e.g.: 10_2

    # parse sex from part of mouse number after '_'; 10_2 -> 2
    # < 6 is male (0) ; > 5 is female (1) 
    females = [
        0 if int(m.split('_')[-1]) < 6 else 1
        for m in mouse_numbers
    ]

    # print('females:', females)
    
    # insert colums
    tx_df.insert(0, 'Name', file_names[0:3]) # file names from above
    tx_df.insert(0, 'mouse_number', mouse_numbers[0:3]) # mouse numbers 
    tx_df['female'] = females[0:3] # < 6 is male (0) ; > 5 is female (1) 

    # print(females, sample_ids, mouse_numbers)
    
    
    # add name of cohort
    if cohort:
        tx_df.insert(0, 'cohort', cohort)

        # add cohort key
        cohort_keys = create_cohort_key(tx_df.cohort, tx_df.mouse_number)
        tx_df.insert(0, 'cohort_key', cohort_keys)

    return tx_df.reset_index(drop=True) # notee drop the original index

# %%
foo(df, cohort_names)
# Out:
#           cohort_key        cohort mouse_number                         Name  \
# 0   sg_8_weeks_10_12    sg_8_weeks        10_12  20220829_run10_GVI-8W-10_12
# 1  sham_8_weeks_1_03  sham_8_weeks         1_03   20220829_run10_GVI-8W-1_03
# 2   sg_16_weeks_2_04   sg_16_weeks         2_04   20220829_run10_GVI-8W-2_04
#
#   mcmv-miR-M23-1-3p (MIMAT0005543) mcmv-miR-M23-1-5p (MIMAT0005542)  \
# 0                               89                               80
# 1                               88                               60
# 2                               75                               82
#
#   mcmv-miR-M23-2 (MIMAT0005545) mcmv-miR-M44-1 (MIMAT0005546)  \
# 0                            22                            37
# 1                            18                            14
# 2                            12                            22
#
#   mcmv-miR-M55-1 (MIMAT0005547) mcmv-miR-M87-1 (MIMAT0005550)  ...  \
# ...

# %%
def transpose_df(df, cohort=None):
    def create_cohort_key(cohorts, mouse_numbers):
        cohort_keys = [
            c + '_' + n
            for c,n in zip(cohorts, mouse_numbers)
        ]
        return cohort_keys
    
    # merge miR and accession values into name col
    # and add as first col in datafame
    names = df.miR.str.cat(' (' + df.accession + ')')
    df.insert(0, 'miR_name', names)

    # now drop miR and accession cols
    df = df.drop(columns=['miR', 'accession'])
    
    # flip/transpose df
    tx_df  = df.transpose()

    # set columns to first row
    tx_df = tx_df.rename(columns=tx_df.iloc[0]).iloc[1:] # set colums to first row
    tx_df.index.name = 'Name'
    tx_df = tx_df.reset_index()
    tx_df.Name = tx_df.Name.astype(str)

    # add mouse numbers to each cohort
    mouse_numbers = list(tx_df['Name'].map(lambda x: x.split('-')[-1]))
    tx_df.insert(0, 'mouse_number', mouse_numbers)

    # add sex info: mice 1-5 are male, rest are female
    tx_df['female'] = np.where(tx_df['mouse_number'].astype(int) < 6, 0, 1)
    
    # add name of cohort
    if cohort:
        tx_df.insert(0, 'cohort', cohort)

        # add cohort key
        cohort_keys = create_cohort_key(tx_df.cohort, tx_df.mouse_number)
        tx_df.insert(0, 'cohort_key', cohort_keys)

    return tx_df

# %%
# transpose_df(test_df)
